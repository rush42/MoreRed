# %%
import os
os.environ["OMP_NUM_THREADS"] = "6" # export OMP_NUM_THREADS=4
os.environ["OPENBLAS_NUM_THREADS"] = "6" # export OPENBLAS_NUM_THREADS=4
os.environ["MKL_NUM_THREADS"] = "6" # export MKL_NUM_THREADS=6

# %%
from matplotlib import pyplot as plt

import torch

from omegaconf import OmegaConf
from ase.visualize.plot import plot_atoms
from ase import Atoms
from schnetpack import properties
import schnetpack.transform as trn
from schnetpack.datasets import QM9
from tqdm import tqdm
import ase

from morered.datasets import QM9Filtered, QM7X
from morered.noise_schedules import PolynomialSchedule, CosineSchedule
from morered.processes import VPGaussianDDPM
from morered.utils import scatter_mean, check_validity, generate_bonds_data, batch_center_systems, batch_rmsd
from morered.sampling import DDPM, MoreRedJT, MoreRedAS, MoreRedITP, ConsistencySampler

# %% [markdown]
# # Structure Generation/Denoising tutorial
#
# This notebook explains how to use the models, for structure relaxation/denoising or generation from scratch, after training. You can find pre-trained models in under "models/" directory.
#
# ## 1. Define sampler
# How to instantiate the different samplers.
#
# ## 2. Define data loader
# How to load data from ase.db database.
#
# ## 3. Relaxating batches of diffused data
# How to diffuse a batch of structures and denoise them using the different models.
#
# ## 4. Load your own xyz file
# How to load molecules from your own xyz files and denoise them.
#
# ## 5. Sample from scratch
# How to sample new stuctures from scratch given an atomic composition.

# %% [markdown]
# # Helper functions

# %%
def plot_batch_molecules(batch):
    n_cols = len(batch[properties.idx_m].unique())
    n_rows = 1

    fig, axs = plt.subplots(n_rows, n_cols, figsize=(3 * n_cols, 3 * n_rows))
    axs = axs.flatten()

    for i, ax in enumerate(axs):
        mask = batch[properties.idx_m] == i
        mol = Atoms(numbers=batch[properties.Z][mask], positions=batch[properties.R][mask])

        plot_atoms(mol, ax)
        ax.axis("off")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Paths

# %%
# path to store the dataset as ASE '.db' files
split_file_path = "split.npz"

# model path
models_path = "../models"

# %% [markdown]
# # Load model

# %%
# consistency mean predictor
mean_predictor = torch.load(os.path.join(models_path, "consistency.pt"), map_location="cpu")
# Out:
# /tmp/ipykernel_1705101/1484588224.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   mean_predictor = torch.load(os.path.join(models_path, "consistency.pt"), map_location="cpu")

# %% [markdown]
# # Define sampler

# %%
# define the noise schedule
# noise_schedule = CosineSchedule(T=32, s=1e-5, v=2.5, dtype=torch.float64)
noise_schedule = PolynomialSchedule(T=64, s=1e-5, dtype=torch.float64, variance_type="lower_bound")

# define the forward diffusion process
diff_proc = VPGaussianDDPM(noise_schedule, noise_key="eps", invariant=True, dtype=torch.float64)

# %%
consistency_sampler = ConsistencySampler(
    diff_proc,
    mean_predictor,
    time_key = "t",
    time_pred_key="t_pred",
    mean_pred_key="mu_pred",
    cutoff=5.,
    recompute_neighbors=False,
    save_progress= True,
    progress_stride = 1,
    results_on_cpu = True,
)

# %% [markdown]
# # Define data loader

# %% [markdown]
# Define paths

# %%
tut_path = "./tut"

# %%
os.makedirs(tut_path, exist_ok=True)

# %% [markdown]
# Define data input transformations

# %%
transforms=[
    trn.CastTo64(),
    trn.SubtractCenterOfGeometry(),
]

# %% [markdown]
# Define dataset

# %% [markdown]
# QM9

# %%
# path to store the dataset as ASE '.db' files
datapath = os.path.join(tut_path, "qm9.db")

# %%
data = QM9Filtered(
    datapath=datapath,
    batch_size=8,
    remove_uncharacterized=True,
    num_train=3000,
    num_val=3000,
    num_test=3000,
    transforms=transforms,
    num_workers=2,
    pin_memory=False,
)

# %% [markdown]
# QM7X

# %% [markdown]
# NOTE! QM7-X is large. Therefore, it takes time to download the dataset and prepare it

# %%
# path to store the dataset as ASE '.db' files
# datapath = os.path.join(tut_path, "qm7x.db")

# %%
# data = QM7X(
#     datapath=datapath,
#     only_equilibrium=False,
#     batch_size=8,
#     transforms=transforms,
#     num_train=128,
#     num_val=128,
#     num_test=128,
#     num_workers=2,
#     pin_memory=False,
#     load_properties=["rmsd"],
# )

# %% [markdown]
# Prepare dataset

# %%
# prepare and setup the dataset
data.prepare_data()
data.setup()

# %% [markdown]
# # Relaxing batches of diffused data

# %% [markdown]
# Load a batch

# %%
# train split here is not the same as during training
target = next(iter(data.train_dataloader()))

# %%
plot_batch_molecules(target)

# %% [markdown]
# ### Diffuse the batch

# %%
# define the time step
t = 20

# %%
batch = {key: val.clone() for key, val in target.items()}
batch[properties.R], _ = diff_proc.diffuse(batch[properties.R], batch[properties.idx_m], t=torch.tensor(t))

# %%
# check if the centre of geometry for the molecules and sampled noise is zero
assert (scatter_mean(batch[properties.R], batch[properties.idx_m], batch[properties.n_atoms]) < 1e-5).all()

# %%
plot_batch_molecules(batch)

# %% [markdown]
# ### Denoise

# %%
# consistency don't need time steps but max_steps give the number of sample iteration
relaxed_consistency, _, _ = consistency_sampler.denoise(batch, t=t, max_iters=1)
relaxed_consistency_ms, _, _ = consistency_sampler.denoise(batch, t=t, max_iters=2)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 14.46it/s]

# %%
tmp_batch = {key: val.clone() for key, val in batch.items()}

print("Sanity Check: ", batch_rmsd(target[properties.R], target))

tmp_batch.update(relaxed_consistency)
print("RMSD per example Consistency Sampler: ", batch_rmsd(target[properties.R], tmp_batch))

tmp_batch.update(relaxed_consistency_ms)
print("RMSD per example Consistency-MS Sampler: ", batch_rmsd(target[properties.R], tmp_batch))

tmp_batch.update(batch)
print("RMSD per diffused example : ", batch_rmsd(target[properties.R], tmp_batch))
# Out:
# Sanity Check:  tensor([0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.4202e-16,
#         0.0000e+00, 0.0000e+00], dtype=torch.float64)
# RMSD per example Consistency Sampler:  tensor([0.6139, 0.7209, 0.5585, 0.5405, 0.7949, 0.7834, 0.4696, 0.5205],
#        dtype=torch.float64)
# RMSD per example Consistency-MS Sampler:  tensor([0.6141, 0.7507, 0.5355, 0.5335, 0.7769, 0.7777, 0.4467, 0.4905],
#        dtype=torch.float64)
# RMSD per diffused example :  tensor([0.7704, 0.8075, 0.6882, 0.7462, 0.9580, 0.8699, 0.6476, 0.7090],
#        dtype=torch.float64)

# %%
# plot the different examples
tmp_batch = {key: val.clone() for key, val in batch.items()}

print("Target:")
plot_batch_molecules(target)

print("Consistency:")
tmp_batch.update(relaxed_consistency)
plot_batch_molecules(tmp_batch)

print("Consistency-Ms:")
tmp_batch.update(relaxed_consistency)
plot_batch_molecules(tmp_batch)

print("Diffused:")
plot_batch_molecules(batch)
# Out:
# Target:
# Consistency:
# Consistency-Ms:
# Diffused:
